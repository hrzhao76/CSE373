# %%
import os
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams["font.size"]=20

# %%
path = Path("../../experiment")

# %%
fig1, ax = plt.subplots()
plt.xlabel("N")
plt.ylabel("Average runtime(s)")    
plt.title("Finder Runtime Analysis")

for csv_file in path.glob("*.csv"):
    table = pd.read_csv(csv_file, header=None) 
    # plot
    
    ax.plot(table[0], table[1], linewidth=2.0, label =csv_file.name)
    
ax.legend()
ax.set_yscale('log')
ax.set_ylim(10e-6,1)

fig1.savefig("./runtime_log.png")

# %%
fig_linear, ax = plt.subplots()
plt.xlabel("N")
plt.ylabel("Average runtime(s)")    
plt.title("Finder Runtime Analysis")

for csv_file in path.glob("*.csv"):
    table = pd.read_csv(csv_file, header=None) 
    # plot
    
    ax.plot(table[0], table[1], linewidth=2.0, label =csv_file.name)
    
ax.legend()

ax.set_ylim(10e-6,1)

fig_linear.savefig("./runtime_linear.png")

# %%
fig2, ax = plt.subplots()
plt.xlabel("N")
plt.ylabel("Average runtime(s)")    
plt.title("Finder Runtime Analysis")

for csv_file in path.glob("Adj*.csv"):
    table = pd.read_csv(csv_file, header=None) 
    # plot
    
    ax.plot(table[0], table[1], linewidth=2.0, label =csv_file.name)
    
ax.legend()
ax.set_yscale('log')
ax.set_ylim(10e-4,1)
# Out:
# (0.001, 1)

# %%
fig3, ax = plt.subplots()
plt.xlabel("N")
plt.ylabel("Average runtime(s)")    
plt.title("Finder Runtime Analysis")

for csv_file in path.glob("Gen*.csv"):
    table = pd.read_csv(csv_file, header=None) 
    # plot
    
    ax.plot(table[0], table[1], linewidth=2.0, label =csv_file.name)
    
ax.legend()
ax.set_yscale('log')
ax.set_ylim(10e-4,1)
# Out:
# (0.001, 1)

# %%
fig4, ax = plt.subplots()
plt.xlabel("N")
plt.ylabel("Average runtime(s)")    
plt.title("Finder Runtime Analysis")

for csv_file in path.glob("Dyn*.csv"):
    table = pd.read_csv(csv_file, header=None) 
    # plot
    
    ax.plot(table[0], table[1], linewidth=2.0, label =csv_file.name)
    
ax.legend()
ax.set_yscale('log')
ax.set_ylim(10e-5,1)
# Out:
# (0.0001, 1)
